# %%
import cv2

# %% [markdown]
# K-Mean

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

#Generate random data points
np.random.seed(0)
data = np.random.rand(100,2)

#Number of clusters
k = 3

#Initialize the KMeans Model
kmeans = KMeans(n_clusters=k)

#Fit the model to the data
kmeans.fit(data)

#Get the cluster centers and labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

#Plot the data points and cluster centers
plt.scatter(data[:,0], data[:,1], c=labels, cmap='viridis')
plt.scatter(centers[:,0], centers[:,1], c='red',marker='X', s=100, label='Cluster Centers')
plt.title('K-Means Clustering')
plt.legend()
plt.show()
# Out:
# C:\Users\Aarya Gupta\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# K-Mean Clustering using NLTK

# %%
import numpy as np 
import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

nltk.download('stopwords')
nltk.download('punkt')

text_data = ["Natural Language Processing is a subfield of AI.",
             "Text mining involves extracting meaningful information from unstructured data.",
            "Machine Learning Algorithms can be applied to analyze text data.",
            "NLP tasks include sentiment analysis,named entity recognition and language translation.",
            "K-Means clustering is a popular unsupervised machine learning algorithm."]

#preprocess text data using word tokenization method in nltk
def preprocess_text(text_data):
    stop_words = set(stopwords.words('english'))
    preprocessed_data = []
    for text in text_data:
        words = word_tokenize(text.lower())
        filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
        preprocessed_data.append(filtered_words)
    return preprocessed_data

preprocessed_data = preprocess_text(text_data)    

#convert preprocessed data into numerical vector using one hot encoding

unique_words = sorted(set(word for sublist in preprocessed_data for word in sublist))
one_hot_vectors = np.zeros((len(preprocessed_data),len(unique_words)))
for i, words in enumerate(preprocessed_data):
    for word in words:
        one_hot_vectors[i, unique_words.index(word)] = 1
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>

# %%
#Initialize number of clusters and KMeans Model
k = 2
kmeans = KMeans(n_clusters=k)
kmeans.fit(one_hot_vectors)
centers = kmeans.cluster_centers_
labels = kmeans.labels_

plt.scatter(centers[:,0], centers[:,1], c='blue', marker='X', s=100, label='Cluster Centers')
plt.title('K-Means Clustering on Text Data using NLTK')
plt.legend()
plt.show()
# Out:
# C:\Users\Aarya Gupta\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
