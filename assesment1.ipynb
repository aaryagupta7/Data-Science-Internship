# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('tested.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean()) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data = data.drop(columns=['Cabin'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB

# %%
data['Age'] = data['Age'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    int32
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(4)
# memory usage: 34.4+ KB

# %%
pivot_table = pd.pivot_table(data,values='Age',index='PassengerId',columns='Sex')
pivot_table
# Out:
# Sex          female  male
# PassengerId
# 892             NaN  34.0
# 893            47.0   NaN
# 894             NaN  62.0
# 895             NaN  27.0
# 896            22.0   NaN
# ...             ...   ...
# 1305            NaN  30.0
# 1306           39.0   NaN
# 1307            NaN  38.0
# 1308            NaN  30.0
# 1309            NaN  30.0
#
# [418 rows x 2 columns]

# %%
arr2 = np.array(data['Sex'].value_counts())
print(type(arr2))
print(arr2)
print(data['Sex'].value_counts())
# Out:
# <class 'numpy.ndarray'>
# [266 152]
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
arr = ['Male','Female']
ax.pie(arr2,labels=arr,autopct='%1.2f%%')
plt.legend(title='Total Population = 418')
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(arr,arr2)
plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ...

# %%
arr = data['Survived'].value_counts()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(arr, labels = ['Survived','Not Survived'],autopct='%1.2f%%')
plt.show()

# %%
data2 = data[data['Survived']==1]
data2.info()
data2['Sex'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 1 to 414
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  152 non-null    int64
#  1   Survived     152 non-null    int64
#  2   Pclass       152 non-null    int64
#  3   Name         152 non-null    object
#  4   Sex          152 non-null    object
#  5   Age          152 non-null    int32
#  6   SibSp        152 non-null    int64
#  7   Parch        152 non-null    int64
#  8   Ticket       152 non-null    object
#  9   Fare         152 non-null    float64
#  10  Embarked     152 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(4)
# memory usage: 13.7+ KB
# Sex
# female    152
# Name: count, dtype: int64

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female   47      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1
# 6                               Connolly, Miss. Kate  female   30      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female   18      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female   23      1
# ..                                               ...     ...  ...    ...
# ...

# %%
fig,ax = plt.subplots(1,1)
a = np.array(data2['Age'])
ax.hist(a, bins= [0,25,50,75,100])
ax.set_title("Number of passengers survived by age group")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('Age')
ax.set_ylabel('Number of Passengers')
plt.show()
